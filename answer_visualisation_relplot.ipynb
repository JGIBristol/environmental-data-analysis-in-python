# %%
import pandas as pd

tips = pd.read_csv("tips.csv")  # TODO update to URL

# %%
tips["bill_per_person"] = tips["total_bill"] / tips["size"]
tips["percent_tip"] = (tips["tip"] / tips["total_bill"])*100

# %%
import seaborn as sns

sns.relplot(data=tips, x="bill_per_person", y="percent_tip", hue="day", col="time")
